# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 20})
import os
file_prefix = '/Users/jclialex/PycharmProjects/whiteboxmi_expdata/expdata/simplex/'
file_name = 'track_loss_0_server_1_-1.0_10_40_0_0.0_0.0_0_0.0_0_cifar10_4000_alexnet.npy'
gd_loss = np.load(file_prefix+file_name)
print (gd_loss.shape)
file_name = 'track_loss_0_server_1_1.0_10_40_0_0.0_0.0_0_0.0_0_cifar10_4000_alexnet.npy'
ga_loss = np.load(file_prefix+file_name)
print (ga_loss.shape)
file_name = 'track_loss_0_server_0_0.0_10_40_0_0.0_0.0_0_0.0_0_cifar10_4000_alexnet.npy'
normal_loss = np.load(file_prefix+file_name)
print (normal_loss.shape)
fig = plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
for i in range(3):
    plt.plot(np.arange(len(gd_loss)),gd_loss[:,i])
    
plt.legend(['train','val','test'])
plt.title('gd')

plt.subplot(1,3,2)
for i in range(3):
    plt.plot(np.arange(len(ga_loss)),ga_loss[:,i])
    
plt.legend(['train','val','test'])
plt.title('ga')

plt.subplot(1,3,3)
for i in range(3):
    plt.plot(np.arange(len(normal_loss)),normal_loss[:,i])
    
plt.legend(['train','val','test'])
plt.title('normal')
plt.show()

print(gd_loss[-1,:])
print(ga_loss[-1,:])
# Out:
# (300, 3)
# (300, 3)
# (300, 3)
# [0.46517071 0.88983336 0.8632849 ]
# [0.46632031 0.78009766 0.85260392]

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
file_prefix = '/Users/jclialex/PycharmProjects/whiteboxmi_expdata/expdata/simplex/'
file_name = 'track_acc_0_server_1_-1.0_10_40_0_0.0_0.0_0_0.0_0_cifar10_4000_alexnet.npy'
gd_loss = np.load(file_prefix+file_name)
print (gd_loss.shape)
file_name = 'track_acc_0_server_1_1.0_10_40_0_0.0_0.0_0_0.0_0_cifar10_4000_alexnet.npy'
ga_loss = np.load(file_prefix+file_name)
print (ga_loss.shape)
file_name = 'track_acc_0_server_0_0.0_10_40_0_0.0_0.0_0_0.0_0_cifar10_4000_alexnet.npy'
normal_loss = np.load(file_prefix+file_name)
print (normal_loss.shape)
fig = plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
for i in range(3):
    plt.plot(np.arange(len(gd_loss)),gd_loss[:,i])
    
plt.legend(['train','val','test'])
plt.title('gd')

plt.subplot(1,3,2)
for i in range(3):
    plt.plot(np.arange(len(ga_loss)),ga_loss[:,i])
    
plt.legend(['train','val','test'])
plt.title('ga')

plt.subplot(1,3,3)
for i in range(3):
    plt.plot(np.arange(len(normal_loss)),normal_loss[:,i])
    
plt.legend(['train','val','test'])
plt.title('no active attack')
plt.show()

print(gd_loss[10,:])
print(ga_loss[10,:])
print (normal_loss[10,:])
# Out:
# (300, 3)
# (300, 3)
# (300, 3)
# [39.2425 41.49   41.22  ]
# [33.325 34.32  33.17 ]
# [36.745 38.16  37.52 ]
