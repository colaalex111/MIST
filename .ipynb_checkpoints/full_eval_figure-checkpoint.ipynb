# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(45,45))
plt.rcParams.update({'font.size': 36})
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
markersize = 20
fontsize=45

### cifar10 alexnet def comp

# 0.5,1,1.5,2,2.5,3,4,4.5,5,6
#test_acc = [71.00,70.50,70.01,69.58,67.38,66.48,65.38,63.57]
#attack_plr = [44.4,35.9,27.0,24.0,22.0,19.0,15.0,10.0]
#attack_auc = [74.1,73.2,71.3,70.8,69.8,68.5,67.10,65.44]

# for user number 4, 2,2.5,3,3.5,4,4.5,5,5.5
#test_acc = [70.50,70.30,69.55,68.86,68.39,67.50,66.79,65.89]
#attack_plr = [27.0,24.0,21.8,18.9,17.3,13.1,9.48,8.78]

# for user number weight 2.5, 3, 3.5, 4, 4.5, 5, need 5.5
test_acc = [71.79,70.89,70.06,69.50,68.98,67.50,66.46]
attack_plr = [30.15,26.63,21.98,16.16,12.09,10.84,8.91]

selena_test_acc = [67.10]
selena_attack_plr = [16.25]
selena_attack_auc = [64.5]

mixup_train_acc = [54.73]
mixup_test_acc = [70.12]
mixup_attack_plr = [125.18]
mixup_attack_auc = [80.5]

dpsgd_test_acc = [69.01,68.44,68.01]
dpsgd_attack_plr = [192,176.10,161.01]

hamp_test_acc =[71.54,70.01,68.37,67.15,65.90]
hamp_attack_plr = [33.58,27.38,16.58,15.61,7.90]


base_test_acc = [69.60]
base_attack_plr = [193.17]
advreg_test_acc = [71.03]
advreg_attack_plr = [135.38]
memguard_test_acc = [70.10]
memguard_attack_plr = [37.70]
dmp_test_acc = [63.11]
dmp_attack_plr = [1.23]

test_acc = np.array(test_acc)/100
selena_test_acc = np.array(selena_test_acc)/100
mixup_test_acc = np.array(mixup_test_acc)/100
dpsgd_test_acc = np.array(dpsgd_test_acc)/100
hamp_test_acc = np.array(hamp_test_acc)/100
base_test_acc = np.array(base_test_acc)/100
advreg_test_acc = np.array(advreg_test_acc)/100
memguard_test_acc = np.array(memguard_test_acc)/100
dmp_test_acc = np.array(dmp_test_acc)/100

base_attack_plr = np.log10(np.array(base_attack_plr))
advreg_attack_plr = np.log10(np.array(advreg_attack_plr))
memguard_attack_plr = np.log10(np.array(memguard_attack_plr))
dmp_attack_plr = np.log10(np.array(dmp_attack_plr))
attack_plr = np.log10(np.array(attack_plr))
selena_attack_plr = np.log10(np.array(selena_attack_plr))
mixup_attack_plr = np.log10(np.array(mixup_attack_plr))
hamp_attack_plr = np.log10(np.array(hamp_attack_plr))
dpsgd_attack_plr = np.log10(np.array(dpsgd_attack_plr))

plt.subplot(3,3,1)
plt.plot(base_test_acc,base_attack_plr,marker='>',color='black',markersize=markersize)
plt.plot(advreg_test_acc,advreg_attack_plr,marker='<',color='purple',markersize=markersize)
plt.plot(memguard_test_acc,memguard_attack_plr,marker='8',color='olive',markersize=markersize)
#plt.plot(dmp_test_acc,dmp_attack_plr,marker='x',color='orchid',markersize=markersize)
plt.plot(test_acc,attack_plr,marker='o',markersize=markersize,color='blue')
plt.plot(selena_test_acc,selena_attack_plr,marker='v',markersize=markersize,color='orange')
plt.plot(mixup_test_acc,mixup_attack_plr,marker='p',markersize=markersize,color='green')
plt.plot(hamp_test_acc,hamp_attack_plr,marker='^',markersize=markersize,color='red')
plt.plot(dpsgd_test_acc,dpsgd_attack_plr,marker='s',markersize=markersize,color='brown')
plt.axvline(x = 0.6960,color='black',linestyle='dashed')

plt.title('AlexNet-CIFAR10')
plt.yticks([0.5,1,1.5,2,2.5],labels=["$10^{0.5}$","$10^{1}$","$10^{1.5}$","$10^{2}$","$10^{2.5}$"])
    
plt.xlabel('test accuracy',fontsize=fontsize)
plt.ylabel('PLR @ FPR = 0.001',fontsize=fontsize)

plt.legend(['No-def','Adv-reg','Mem-guard','MIST+Mixup (ours)','SELENA','Mixup+MMD','HAMP','DPSGD','test acc. w/o any def.'],ncol=5,bbox_to_anchor=(3.05, 1.3),prop={'size': 36})


### cifar10 resnet def comp

test_acc = [88.10,87.20,86.92,86.33,85.95,85.32,84.51]
attack_plr = [18.4,16.58,15.38,14.13,13.3,9.24,4.45]

mixup_test_acc = [86.85]
mixup_attack_plr = [73.60]

#dpsgd_test_acc = [87.19]
#dpsgd_attack_plr = [34.78]

dpsgd_test_acc = [84.78,83.37,83.10]
dpsgd_attack_plr = [209,165,115]

hamp_test_acc =[86.51,83.48,81.92]
hamp_attack_plr = [87.38,54.49,43.59]

base_test_acc = [86.31]
base_attack_plr = [79.30]
#advreg_test_acc = [44.55]
#advreg_attack_plr = [10.29]
memguard_test_acc = [86.30]
memguard_attack_plr = [15.96]
dmp_test_acc = [86.21]
dmp_attack_plr = [20]

test_acc = np.array(test_acc)/100
selena_test_acc = np.array(selena_test_acc)/100
mixup_test_acc = np.array(mixup_test_acc)/100
dpsgd_test_acc = np.array(dpsgd_test_acc)/100
hamp_test_acc = np.array(hamp_test_acc)/100
base_test_acc = np.array(base_test_acc)/100
#advreg_test_acc = np.array(advreg_test_acc)/100
memguard_test_acc = np.array(memguard_test_acc)/100
dmp_test_acc = np.array(dmp_test_acc)/100

base_attack_plr = np.log10(np.array(base_attack_plr))
#advreg_attack_plr = np.log(np.array(advreg_attack_plr))
memguard_attack_plr = np.log10(np.array(memguard_attack_plr))
dmp_attack_plr = np.log10(np.array(dmp_attack_plr))
attack_plr = np.log10(np.array(attack_plr))
selena_attack_plr = np.log10(np.array(selena_attack_plr))
mixup_attack_plr = np.log10(np.array(mixup_attack_plr))
hamp_attack_plr = np.log10(np.array(hamp_attack_plr))
dpsgd_attack_plr = np.log10(np.array(dpsgd_attack_plr))

plt.subplot(3,3,2)
plt.plot(base_test_acc,base_attack_plr,marker='>',color='black',markersize=markersize)
#plt.plot(advreg_test_acc,advreg_attack_plr,marker='<',color='purple',markersize=markersize)
plt.plot(memguard_test_acc,memguard_attack_plr,marker='8',color='olive',markersize=markersize)
#plt.plot(dmp_test_acc,dmp_attack_plr,marker='x',color='orchid',markersize=markersize)
plt.plot(test_acc,attack_plr,marker='o',markersize=markersize,color='blue')
plt.plot(mixup_test_acc,mixup_attack_plr,marker='p',markersize=markersize,color='green')
plt.plot(hamp_test_acc,hamp_attack_plr,marker='^',markersize=markersize,color='red')
plt.plot(dpsgd_test_acc,dpsgd_attack_plr,marker='s',markersize=markersize,color='brown')
plt.axvline(x = 0.8631,color='black',linestyle='dashed')

plt.yticks([0.5,1,1.5,2,2.5],labels=["$10^{0.5}$","$10^{1}$","$10^{1.5}$","$10^{2}$","$10^{2.5}$"])
plt.title('ResNet18-CIFAR10')
plt.xlabel('test accuracy',fontsize=fontsize)
plt.ylabel('PLR @ FPR = 0.001',fontsize=fontsize)
#plt.legend(['Mixup+MIST','SELENA','Mixup+MMD','test acc. w/o any def.'],ncol=2,bbox_to_anchor=(0.75, 1.5),prop={'size': 30})



### cifar10 densenet def comp

test_acc = [89.64,88.87,88.14,86.82,85.19,83.86]
attack_plr = [45,23.48,16.38,14.5,10.8,6.9]

mixup_test_acc = [86.71]
mixup_attack_plr = [92.34]

hamp_test_acc = [87.8,86.59,85.46,84.35]
hamp_attack_plr = [55.0,35.4,30.10,24.12]

dpsgd_test_acc = [86.44,86.10,85.30]
dpsgd_attack_plr = [253.29,230.19,200.01]

base_test_acc = [87.88]
base_attack_plr = [110.49]
#advreg_test_acc = [28.55]
#advreg_attack_plr = [10.29]
memguard_test_acc = [87.79]
memguard_attack_plr = [20.34]
dmp_test_acc = [83.45]
dmp_attack_plr = [12.64]

test_acc = np.array(test_acc)/100
selena_test_acc = np.array(selena_test_acc)/100
mixup_test_acc = np.array(mixup_test_acc)/100
dpsgd_test_acc = np.array(dpsgd_test_acc)/100
hamp_test_acc = np.array(hamp_test_acc)/100
base_test_acc = np.array(base_test_acc)/100
#advreg_test_acc = np.array(advreg_test_acc)/100
memguard_test_acc = np.array(memguard_test_acc)/100
dmp_test_acc = np.array(dmp_test_acc)/100


base_attack_plr = np.log10(np.array(base_attack_plr))
#advreg_attack_plr = np.log(np.array(advreg_attack_plr))
memguard_attack_plr = np.log10(np.array(memguard_attack_plr))
dmp_attack_plr = np.log10(np.array(dmp_attack_plr))
attack_plr = np.log10(np.array(attack_plr))
selena_attack_plr = np.log10(np.array(selena_attack_plr))
mixup_attack_plr = np.log10(np.array(mixup_attack_plr))
hamp_attack_plr = np.log10(np.array(hamp_attack_plr))
dpsgd_attack_plr = np.log10(np.array(dpsgd_attack_plr))

plt.subplot(3,3,3)
plt.plot(base_test_acc,base_attack_plr,marker='>',color='black',markersize=markersize)
#plt.plot(advreg_test_acc,advreg_attack_plr,marker='<',color='purple',markersize=markersize)
plt.plot(memguard_test_acc,memguard_attack_plr,marker='8',color='olive',markersize=markersize)
#plt.plot(dmp_test_acc,dmp_attack_plr,marker='x',color='orchid',markersize=markersize)
plt.plot(test_acc,attack_plr,marker='o',markersize=markersize,color='blue')
plt.plot(mixup_test_acc,mixup_attack_plr,marker='p',markersize=markersize,color='green')
plt.plot(hamp_test_acc,hamp_attack_plr,marker='^',markersize=markersize,color='red')
plt.plot(dpsgd_test_acc,dpsgd_attack_plr,marker='s',markersize=markersize,color='brown')
plt.axvline(x = 0.8788,color='black',linestyle='dashed')

plt.yticks([0.5,1,1.5,2,2.5],labels=["$10^{0.5}$","$10^{1}$","$10^{1.5}$","$10^{2}$","$10^{2.5}$"])
plt.title('DenseNet-CIFAR10')
plt.xlabel('test accuracy',fontsize=fontsize)
plt.ylabel('PLR @ FPR = 0.001',fontsize=fontsize)
#plt.legend(['Mixup+MIST','SELENA','Mixup+MMD','test acc. w/o any def.'],ncol=2,bbox_to_anchor=(0.75, 1.5),prop={'size': 30})

### cifar100 alexnet def comp
train_acc = [43.56,41.27,38.92,37.44,36.60,35.03,33.02,32.89,31.99]
test_acc = [32.71,31.48,30.93,30.43,29.96,28.58,27.97,27.58,26.99,26.27]
attack_plr = [30.1,26.3,22.3,20.9,17.8,15.8,13.7,13.28,8.8,4.4]
attack_auc = [82.0,80.8,79.3,78.1,77.1,76.3,74.8,74.1,73.6]

selena_train_acc = [33.73]
selena_test_acc = [28.79]
selena_attack_plr = [35.9]
selena_attack_auc = [71.9]

mixup_train_acc = [54.73]
mixup_test_acc = [30.18]
mixup_attack_plr = [112.11]
mixup_attack_auc = [93.6]

dpsgd_test_acc = [30.39,29.77,29.10]
dpsgd_attack_plr = [53.74,31.75,20.84]

hamp_test_acc = [25.37,27.49,30.44,31.20]
hamp_attack_plr = [10.48,18.30,33.39,41.2]

base_test_acc = [30.54]
base_attack_plr = [357.37]
advreg_test_acc = [32.22]
advreg_attack_plr = [335.18]
memguard_test_acc = [30.49]
memguard_attack_plr = [218.70]
#dmp_test_acc = []
#dmp_test_plr = []


test_acc = np.array(test_acc)/100
selena_test_acc = np.array(selena_test_acc)/100
mixup_test_acc = np.array(mixup_test_acc)/100
dpsgd_test_acc = np.array(dpsgd_test_acc)/100
hamp_test_acc = np.array(hamp_test_acc)/100
base_test_acc = np.array(base_test_acc)/100
advreg_test_acc = np.array(advreg_test_acc)/100
memguard_test_acc = np.array(memguard_test_acc)/100
#dmp_test_acc = np.array(dmp_test_acc)/100


base_attack_plr = np.log10(np.array(base_attack_plr))
advreg_attack_plr = np.log10(np.array(advreg_attack_plr))
memguard_attack_plr = np.log10(np.array(memguard_attack_plr))
#dmp_attack_plr = np.log(np.array(dmp_attack_plr))
attack_plr = np.log10(np.array(attack_plr))
selena_attack_plr = np.log10(np.array(selena_attack_plr))
mixup_attack_plr = np.log10(np.array(mixup_attack_plr))
hamp_attack_plr = np.log10(np.array(hamp_attack_plr))
dpsgd_attack_plr = np.log10(np.array(dpsgd_attack_plr))

plt.subplot(3,3,4)
plt.plot(base_test_acc,base_attack_plr,marker='>',color='black',markersize=markersize)
plt.plot(advreg_test_acc,advreg_attack_plr,marker='<',color='purple',markersize=markersize)
plt.plot(memguard_test_acc,memguard_attack_plr,marker='8',color='olive',markersize=markersize)
#plt.plot(dmp_test_acc,dmp_attack_plr,marker='x',color='cyan',markersize=markersize)
plt.plot(test_acc,attack_plr,marker='o',markersize=markersize,color='blue')
plt.plot(selena_test_acc,selena_attack_plr,marker='v',markersize=markersize,color='orange')
plt.plot(mixup_test_acc,mixup_attack_plr,marker='p',markersize=markersize,color='green')
plt.plot(hamp_test_acc,hamp_attack_plr,marker='^',markersize=markersize,color='red')
plt.plot(dpsgd_test_acc,dpsgd_attack_plr,marker='s',markersize=markersize,color='brown')
plt.axvline(x = 0.3054,color='black',linestyle='dashed')


plt.yticks([0.5,1,1.5,2,2.5],labels=["$10^{0.5}$","$10^{1}$","$10^{1.5}$","$10^{2}$","$10^{2.5}$"])
plt.title('AlexNet-CIFAR100')
plt.xlabel('test accuracy',fontsize=fontsize)
plt.ylabel('PLR @ FPR = 0.001',fontsize=fontsize)



### cifar100 resnet def comp

test_acc = [53.24,52.89,52.02,51.48,51.01]
attack_plr = [97.19,78.99,68.34,66.89,60.27]

mixup_test_acc = [51.97]
mixup_attack_plr = [259.3]

hamp_test_acc = [51.88,50.12,48.91]
hamp_attack_plr = [412.31,240,101.28]

dpsgd_test_acc = [52.12,50.99,49.74]
dpsgd_attack_plr = [300.4,220,173]

base_test_acc = [53.01]
base_attack_plr = [354.08]
advreg_test_acc = [44.55]
advreg_attack_plr = [10.29]
memguard_test_acc = [52.98]
memguard_attack_plr = [96.82]
dmp_test_acc = [51.11]
dmp_attack_plr = [2.64]

test_acc = np.array(test_acc)/100
selena_test_acc = np.array(selena_test_acc)/100
mixup_test_acc = np.array(mixup_test_acc)/100
dpsgd_test_acc = np.array(dpsgd_test_acc)/100
hamp_test_acc = np.array(hamp_test_acc)/100
base_test_acc = np.array(base_test_acc)/100
advreg_test_acc = np.array(advreg_test_acc)/100
memguard_test_acc = np.array(memguard_test_acc)/100
dmp_test_acc = np.array(dmp_test_acc)/100

base_attack_plr = np.log10(np.array(base_attack_plr))
advreg_attack_plr = np.log10(np.array(advreg_attack_plr))
memguard_attack_plr = np.log10(np.array(memguard_attack_plr))
dmp_attack_plr = np.log10(np.array(dmp_attack_plr))
attack_plr = np.log10(np.array(attack_plr))
selena_attack_plr = np.log10(np.array(selena_attack_plr))
mixup_attack_plr = np.log10(np.array(mixup_attack_plr))
hamp_attack_plr = np.log10(np.array(hamp_attack_plr))
dpsgd_attack_plr = np.log10(np.array(dpsgd_attack_plr))

plt.subplot(3,3,5)
plt.plot(base_test_acc,base_attack_plr,marker='>',color='black',markersize=markersize)
#plt.plot(advreg_test_acc,advreg_attack_plr,marker='<',color='purple',markersize=markersize)
plt.plot(memguard_test_acc,memguard_attack_plr,marker='8',color='olive',markersize=markersize)
#plt.plot(dmp_test_acc,dmp_attack_plr,marker='x',color='orchid',markersize=markersize)
plt.plot(test_acc,attack_plr,marker='o',markersize=markersize,color='blue')
#plt.plot(selena_test_acc,selena_attack_plr,marker='v',markersize=markersize,color='orange')
plt.plot(mixup_test_acc,mixup_attack_plr,marker='p',markersize=markersize,color='green')
plt.plot(hamp_test_acc,hamp_attack_plr,marker='^',markersize=markersize,color='red')
plt.plot(dpsgd_test_acc,dpsgd_attack_plr,marker='s',markersize=markersize,color='brown')
plt.axvline(x = 0.5301,color='black',linestyle='dashed')
#plt.legend(['Mixup+MIST','Mixup+MMD','HAMP','test acc. w/o any def.'],ncol=2,bbox_to_anchor=(1.8, 1.5),prop={'size': 30})


plt.yticks([1.5,2,2.5],labels=["$10^{1.5}$","$10^{2}$","$10^{2.5}$"])
plt.title('ResNet18-CIFAR100')
plt.xlabel('test accuracy',fontsize=fontsize)
plt.ylabel('PLR @ FPR = 0.001',fontsize=fontsize)
#plt.legend(['Mixup+MIST','SELENA','Mixup+MMD','test acc. w/o any def.'],ncol=2,bbox_to_anchor=(0.75, 1.5),prop={'size': 30})


### cifar100 densenet def comp

test_acc = [56.62,55.45,53.76,51.88,50.10]
attack_plr = [31.13,28.38,20.38,12.10,7.30]

mixup_test_acc = [51.77]
mixup_attack_plr = [272.22]

hamp_test_acc = [53.18,51.84,49.15]
hamp_attack_plr = [50,40.07,30.39]

dpsgd_test_acc = [53.28,51.73,50.30]
dpsgd_attack_plr = [47.8,35.3,25.3]

base_test_acc = [52.11]
base_attack_plr = [395.08]
#advreg_test_acc = [28.55]
#advreg_attack_plr = [10.29]
memguard_test_acc = [52.09]
memguard_attack_plr = [42.07]
dmp_test_acc = [40.46]
dmp_attack_plr = [12.64]

test_acc = np.array(test_acc)/100
selena_test_acc = np.array(selena_test_acc)/100
mixup_test_acc = np.array(mixup_test_acc)/100
dpsgd_test_acc = np.array(dpsgd_test_acc)/100
hamp_test_acc = np.array(hamp_test_acc)/100
base_test_acc = np.array(base_test_acc)/100
#advreg_test_acc = np.array(advreg_test_acc)/100
memguard_test_acc = np.array(memguard_test_acc)/100
dmp_test_acc = np.array(dmp_test_acc)/100

base_attack_plr = np.log10(np.array(base_attack_plr))
#advreg_attack_plr = np.log(np.array(advreg_attack_plr))
memguard_attack_plr = np.log10(np.array(memguard_attack_plr))
dmp_attack_plr = np.log10(np.array(dmp_attack_plr))
attack_plr = np.log10(np.array(attack_plr))
selena_attack_plr = np.log10(np.array(selena_attack_plr))
mixup_attack_plr = np.log10(np.array(mixup_attack_plr))
hamp_attack_plr = np.log10(np.array(hamp_attack_plr))
dpsgd_attack_plr = np.log10(np.array(dpsgd_attack_plr))

plt.subplot(3,3,6)
plt.plot(base_test_acc,base_attack_plr,marker='>',color='black',markersize=markersize)
#plt.plot(advreg_test_acc,advreg_attack_plr,marker='<',color='purple',markersize=markersize)
plt.plot(memguard_test_acc,memguard_attack_plr,marker='8',color='olive',markersize=markersize)
#plt.plot(dmp_test_acc,dmp_attack_plr,marker='x',color='orchid',markersize=markersize)
plt.plot(test_acc,attack_plr,marker='o',markersize=markersize,color='blue')
plt.plot(mixup_test_acc,mixup_attack_plr,marker='p',markersize=markersize,color='green')
plt.plot(hamp_test_acc,hamp_attack_plr,marker='^',markersize=markersize,color='red')
plt.plot(dpsgd_test_acc,dpsgd_attack_plr,marker='s',markersize=markersize,color='brown')
plt.axvline(x = 0.5211,color='black',linestyle='dashed')
#plt.legend(['Mixup+MIST','Mixup+MMD','HAMP','test acc. w/o any def.'],ncol=2,bbox_to_anchor=(1.8, 1.5),prop={'size': 30})

plt.yticks([0.5,1,1.5,2,2.5],labels=["$10^{0.5}$","$10^{1}$","$10^{1.5}$","$10^{2}$","$10^{2.5}$"])
plt.title('DenseNet-CIFAR100')
plt.xlabel('test accuracy',fontsize=fontsize)
plt.ylabel('PLR @ FPR = 0.001',fontsize=fontsize)
#plt.legend(['Mixup+MIST','SELENA','Mixup+MMD','test acc. w/o any def.'],ncol=2,bbox_to_anchor=(0.75, 1.5),prop={'size': 30})


### texas def comp

# 5,10,20,30,40,50,60,70
test_acc = [57.38,56.38,55.35]
attack_plr = [8.91,8.01,7.28]
#attack_auc = [55.8]

selena_test_acc = [53.66]
selena_attack_plr = [8.14]
#selena_attack_auc = [54.89]

mixup_test_acc = [55.98]
mixup_attack_plr = [8.33]

hamp_test_acc = [51.90]
hamp_attack_plr = [8.01]

dpsgd_test_acc = [56.82,54.74,52.68]
dpsgd_attack_plr = [9.8,9.4,8.9]

base_test_acc = [56.79]
base_attack_plr = [12.64]
#advreg_test_acc = [28.55]
#advreg_attack_plr = [10.29]
memguard_test_acc = [56.79]
memguard_attack_plr = [11.22]
#dmp_test_acc = [40.46]
#dmp_attack_plr = [12.64]

test_acc = np.array(test_acc)/100
selena_test_acc = np.array(selena_test_acc)/100
mixup_test_acc = np.array(mixup_test_acc)/100
dpsgd_test_acc = np.array(dpsgd_test_acc)/100
hamp_test_acc = np.array(hamp_test_acc)/100
base_test_acc = np.array(base_test_acc)/100
#advreg_test_acc = np.array(advreg_test_acc)/100
memguard_test_acc = np.array(memguard_test_acc)/100
#dmp_test_acc = np.array(dmp_test_acc)/100


base_attack_plr = np.log10(np.array(base_attack_plr))
#advreg_attack_plr = np.log(np.array(advreg_attack_plr))
memguard_attack_plr = np.log10(np.array(memguard_attack_plr))
#dmp_attack_plr = np.log(np.array(dmp_attack_plr))
attack_plr = np.log10(np.array(attack_plr))
selena_attack_plr = np.log10(np.array(selena_attack_plr))
mixup_attack_plr = np.log10(np.array(mixup_attack_plr))
hamp_attack_plr = np.log10(np.array(hamp_attack_plr))
dpsgd_attack_plr = np.log10(np.array(dpsgd_attack_plr))

plt.subplot(3,3,7)
plt.plot(base_test_acc,base_attack_plr,marker='>',color='black',markersize=markersize)
#plt.plot(advreg_test_acc,advreg_attack_plr,marker='<',color='purple',markersize=markersize)
plt.plot(memguard_test_acc,memguard_attack_plr,marker='8',color='olive',markersize=markersize)
#plt.plot(dmp_test_acc,dmp_attack_plr,marker='x',color='orchid',markersize=markersize)
plt.plot(test_acc,attack_plr,marker='o',markersize=markersize,color='blue')
#plt.plot(selena_test_acc,selena_attack_plr,marker='v',markersize=markersize,color='orange')
plt.plot(mixup_test_acc,mixup_attack_plr,marker='p',markersize=markersize,color='green')
plt.plot(hamp_test_acc,hamp_attack_plr,marker='^',markersize=markersize,color='red')
plt.plot(dpsgd_test_acc,dpsgd_attack_plr,marker='s',markersize=markersize,color='brown')
plt.axvline(x = 0.5679,color='black',linestyle='dashed')
#plt.legend(['MIST','SELENA','MMD','HAMP','test acc. w/o any def.'],ncol=2,bbox_to_anchor=(0.55, 1.5),prop={'size': 30})
plt.yticks([0.5,1,1.5],labels=["$10^{0.5}$","$10^{1}$","$10^{1.5}$"])
plt.title('TEXAS')
plt.xlabel('test accuracy',fontsize=fontsize)
plt.ylabel('PLR @ FPR = 0.001',fontsize=fontsize)

### purchase def comp, 

test_acc = [90.39,89.93,89.44,89.20]
attack_plr = [1.5,1.3,1.21,1.05]

selena_test_acc = [87.29]
selena_attack_plr = [1.39]

mixup_test_acc = [90.01]
mixup_attack_plr = [1.37]
mixup_attack_auc = [65.64]

hamp_test_acc = [83.53]
hamp_attack_plr = [4.08]

dpsgd_test_acc =[90.20,89.99,89.55]
dpsgd_attack_plr = [1.8,1.5,1.3]

base_test_acc = [90.17]
base_attack_plr = [1.55]
#advreg_test_acc = [28.55]
#advreg_attack_plr = [10.29]
memguard_test_acc = [90.17]
memguard_attack_plr = [1.58]
#dmp_test_acc = [40.46]
#dmp_attack_plr = [12.64]

test_acc = np.array(test_acc)/100
selena_test_acc = np.array(selena_test_acc)/100
mixup_test_acc = np.array(mixup_test_acc)/100
dpsgd_test_acc = np.array(dpsgd_test_acc)/100
hamp_test_acc = np.array(hamp_test_acc)/100
base_test_acc = np.array(base_test_acc)/100
#advreg_test_acc = np.array(advreg_test_acc)/100
memguard_test_acc = np.array(memguard_test_acc)/100
#dmp_test_acc = np.array(dmp_test_acc)/100


base_attack_plr = np.log10(np.array(base_attack_plr))
#advreg_attack_plr = np.log(np.array(advreg_attack_plr))
memguard_attack_plr = np.log10(np.array(memguard_attack_plr))
#dmp_attack_plr = np.log(np.array(dmp_attack_plr))
attack_plr = np.log10(np.array(attack_plr))
selena_attack_plr = np.log10(np.array(selena_attack_plr))
mixup_attack_plr = np.log10(np.array(mixup_attack_plr))
hamp_attack_plr = np.log10(np.array(hamp_attack_plr))
dpsgd_attack_plr = np.log10(np.array(dpsgd_attack_plr))

plt.subplot(3,3,8)
plt.plot(base_test_acc,base_attack_plr,marker='>',color='black',markersize=markersize)
#plt.plot(advreg_test_acc,advreg_attack_plr,marker='<',color='purple',markersize=markersize)
plt.plot(memguard_test_acc,memguard_attack_plr,marker='8',color='olive',markersize=markersize)
#plt.plot(dmp_test_acc,dmp_attack_plr,marker='x',color='orchid',markersize=markersize)
plt.plot(test_acc,attack_plr,marker='o',markersize=markersize,color='blue')
plt.plot(selena_test_acc,selena_attack_plr,marker='v',markersize=markersize,color='orange')
plt.plot(mixup_test_acc,mixup_attack_plr,marker='p',markersize=markersize,color='green')
#plt.plot(hamp_test_acc,hamp_attack_plr,marker='^',markersize=markersize,color='red')
plt.plot(dpsgd_test_acc,dpsgd_attack_plr,marker='s',markersize=markersize,color='brown')
plt.axvline(x = 0.9017,color='black',linestyle='dashed')
#plt.legend(['MIST','SELENA','MMD','HAMP','test acc. w/o any def.'],ncol=2,bbox_to_anchor=(0.55, 1.5),prop={'size': 30})
plt.yticks([0,0.5],labels=["$10^{0}$","$10^{0.5}$"])
plt.title('PURCHASE')
plt.xlabel('test accuracy',fontsize=fontsize)
plt.ylabel('PLR @ FPR = 0.001',fontsize=fontsize)

### location 

test_acc = [73.50,72.07,69,67.9]
attack_plr = [1.7,1.15,1.10,1.06]

selena_test_acc = [66.47]
selena_attack_plr = [4.81]
selena_attack_auc = [65.92]

mixup_test_acc = [69.01]
mixup_attack_plr = [17.75]

hamp_test_acc = [71.18,69.22,67.06]
hamp_attack_plr = [21.56,7.54,1.81]

dpsgd_test_acc =[71.13,70.78,69.48]
dpsgd_attack_plr = [3.78,2.78,2.03]

base_test_acc = [72.13]
base_attack_plr = [2.89]
advreg_test_acc = [64.10]
advreg_attack_plr = [2.87]
memguard_test_acc = [71.43]
memguard_attack_plr = [1.36]
#dmp_test_acc = [40.46]
#dmp_attack_plr = [12.64]

test_acc = np.array(test_acc)/100
selena_test_acc = np.array(selena_test_acc)/100
mixup_test_acc = np.array(mixup_test_acc)/100
dpsgd_test_acc = np.array(dpsgd_test_acc)/100
hamp_test_acc = np.array(hamp_test_acc)/100
base_test_acc = np.array(base_test_acc)/100
advreg_test_acc = np.array(advreg_test_acc)/100
memguard_test_acc = np.array(memguard_test_acc)/100
#dmp_test_acc = np.array(dmp_test_acc)/100

base_attack_plr = np.log10(np.array(base_attack_plr))
advreg_attack_plr = np.log10(np.array(advreg_attack_plr))
memguard_attack_plr = np.log10(np.array(memguard_attack_plr))
#dmp_attack_plr = np.log(np.array(dmp_attack_plr))
attack_plr = np.log10(np.array(attack_plr))
selena_attack_plr = np.log10(np.array(selena_attack_plr))
mixup_attack_plr = np.log10(np.array(mixup_attack_plr))
hamp_attack_plr = np.log10(np.array(hamp_attack_plr))
dpsgd_attack_plr = np.log10(np.array(dpsgd_attack_plr))

plt.subplot(3,3,9)
plt.plot(base_test_acc,base_attack_plr,marker='>',color='black',markersize=markersize)
#plt.plot(advreg_test_acc,advreg_attack_plr,marker='<',color='purple',markersize=markersize)
plt.plot(memguard_test_acc,memguard_attack_plr,marker='8',color='olive',markersize=markersize)
#plt.plot(dmp_test_acc,dmp_attack_plr,marker='x',color='orchid',markersize=markersize)
plt.plot(test_acc,attack_plr,marker='o',markersize=markersize,color='blue')
plt.plot(selena_test_acc,selena_attack_plr,marker='v',markersize=markersize,color='orange')
plt.plot(mixup_test_acc,mixup_attack_plr,marker='p',markersize=markersize,color='green')
plt.plot(hamp_test_acc,hamp_attack_plr,marker='^',markersize=markersize,color='red')
plt.plot(dpsgd_test_acc,dpsgd_attack_plr,marker='s',markersize=markersize,color='brown')
plt.axvline(x = 0.7213,color='black',linestyle='dashed')
#plt.legend(['MIST','SELENA','MMD','HAMP','test acc. w/o any def.'],ncol=2,bbox_to_anchor=(0.55, 1.5),prop={'size': 30})
plt.yticks([0,0.5,1,1.5],labels=["$10^{0}$","$10^{0.5}$","$10^{1}$","$10^{1.5}$"])
plt.title('LOCATION')
plt.xlabel('test accuracy',fontsize=fontsize)
plt.ylabel('PLR @ FPR = 0.001',fontsize=fontsize)

plt.savefig('comp_with_hamp.pdf',dpi=3600,bbox_inches="tight")

plt.show()

# %%
all_def_names = ['mist','base','selena','dpsgd','hamp','advreg','memguard','dmp']
all_dataset_names = ['alexnet-cifar10','alxnet-cifar100','resnet-cifar10','resnet-cifar100','densenet-cifar10',\
                    'densenet-cifar100','texas','purchase','location']
test_acc_dict = {x:{y:[] for y in all_dataset_names} for x in all_def_names}
attack_plr_dict ={x:{y:[] for y in all_dataset_names} for x in all_def_names}
